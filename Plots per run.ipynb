# %%
# https://plot.ly/python/axes/
import pandas as pd
import numpy as np

# %%
# Files Configurations
files_header = True
base_folder = "final/Analises/"

# Get the data (csv file should be on the same folder as this file)
def get_algorithm_data(algorithm, parent_folder=base_folder, i=1):
    file = parent_folder + algorithm + "_results_0" + str(i) + ".csv"
    print("Reading file: " + file)
    return pd.read_csv(file, sep=',')

# %%
# Number of runs
runs = [1, 2, 3]

# Variables and Objective columns
vars_cols = ["α1", "y1", "α2", "y2", "α3", "y3"]
objs_cols = ["O1", "O2"]


def get_objs_cols(d):
    return d.columns[9:11]

def get_vars_cols(d):
    return d.columns[3:9]

def get_time_cols(d):
    return d.columns[0:3]


# Drop columns (Time total, t1, t2)
drop_cols = ["Total time (s)", "Time o1", "Time o2"]

# %%
# Objectives
o1 = objs_cols[0]
o2 = objs_cols[1]

# %%
# Algorithms 
#algorithms = ["MOEAD", "SMPSO", "EpsMOEA"]
# algorithms = ["MOEAD", "SPEA2", "NSGAII", "OMOPSO", "SMPSO", "PESA2", "PAES", "EpsMOEA"]
algorithms = ["MOEAD", "SPEA2", "NSGAII", "OMOPSO", "SMPSO", "PESA2", "PAES", "EpsMOEA", "GDE3", "CMAES"]
#algorithms = ["MOEAD", "SPEA2", "NSGAII", "PESA2", "PAES", "EpsMOEA"]

# %%
metamodel_algorithms = []
metamodel_algorithms_metamodels = [ 'GPR', 'RF', 'MLP'] 
metamodel_algorithms_strategies = ['NSGAII', "Random", "SMPSO"]

for metamodel in metamodel_algorithms_metamodels:
    for strategy in metamodel_algorithms_strategies:
        algo = metamodel + "_" + strategy
        print(algo)
        metamodel_algorithms += [algo]
# Out:
# GPR_NSGAII
# GPR_Random
# GPR_SMPSO
# RF_NSGAII
# RF_Random
# RF_SMPSO
# MLP_NSGAII
# MLP_Random
# MLP_SMPSO

# %%
algorithms.extend(metamodel_algorithms)

# %%
len(algorithms)
# Out:
# 19

# %%
def weakly_dominates(v0, v1):
    return np.all(v0 <= v1) and np.any(v0 < v1)

# %%
def get_non_dominated(V):
    nsols, nobjs = V.shape
    
    dominated = np.zeros((nsols, 1))
    dominated_by = np.zeros((nsols, 1))
    
    for i in range(nsols):
        for j in range(nsols):
            if i != j:
                if weakly_dominates(V[j], V[i]):
                    dominated[i] = 1
                    dominated_by[i] = j 
                    break
                    
    return dominated, dominated_by
        
def add_isdominated_cols(d, cols=objs_cols):
    A = np.array(d[cols])
    B, C = get_non_dominated(A)
    d["isDominated"] = pd.DataFrame(B, columns=["isDominated"])
    d["dominatedBy"] = pd.DataFrame(C, columns=["dominatedBy"])
    print(d["isDominated"].value_counts())

# %%
import itertools
algs_runs = list(itertools.product(algorithms, runs))
algs_runs
# Out:
# [('MOEAD', 1),
#  ('MOEAD', 2),
#  ('MOEAD', 3),
#  ('SPEA2', 1),
#  ('SPEA2', 2),
#  ('SPEA2', 3),
#  ('NSGAII', 1),
#  ('NSGAII', 2),
#  ('NSGAII', 3),
#  ('OMOPSO', 1),
#  ('OMOPSO', 2),
#  ('OMOPSO', 3),
#  ('SMPSO', 1),
#  ('SMPSO', 2),
#  ('SMPSO', 3),
#  ('PESA2', 1),
#  ('PESA2', 2),
#  ('PESA2', 3),
#  ('PAES', 1),
#  ('PAES', 2),
#  ('PAES', 3),
#  ('EpsMOEA', 1),
#  ('EpsMOEA', 2),
#  ('EpsMOEA', 3),
#  ('GDE3', 1),
#  ('GDE3', 2),
#  ('GDE3', 3),
#  ('CMAES', 1),
#  ('CMAES', 2),
#  ('CMAES', 3),
#  ('GPR_NSGAII', 1),
#  ('GPR_NSGAII', 2),
#  ('GPR_NSGAII', 3),
#  ('GPR_Random', 1),
#  ('GPR_Random', 2),
#  ('GPR_Random', 3),
#  ('GPR_SMPSO', 1),
#  ('GPR_SMPSO', 2),
#  ('GPR_SMPSO', 3),
#  ('RF_NSGAII', 1),
#  ('RF_NSGAII', 2),
#  ('RF_NSGAII', 3),
#  ('RF_Random', 1),
#  ('RF_Random', 2),
#  ('RF_Random', 3),
#  ('RF_SMPSO', 1),
#  ('RF_SMPSO', 2),
#  ('RF_SMPSO', 3),
#  ('MLP_NSGAII', 1),
#  ('MLP_NSGAII', 2),
#  ('MLP_NSGAII', 3),
#  ('MLP_Random', 1),
#  ('MLP_Random', 2),
#  ('MLP_Random', 3),
#  ('MLP_SMPSO', 1),
#  ('MLP_SMPSO', 2),
#  ('MLP_SMPSO', 3)]

# %%
# Collect data for each algorithm
dfs = [get_algorithm_data(alg, i=i) for alg, i in algs_runs]
# Add isDominated column for each algorithm
for i in range(len(algs_runs)):
    print("\tAlgorithm_run ", algs_runs[i], "\nRetrieved", len(dfs[i]), "solutions")
    dfs[i].drop(drop_cols, axis=1, inplace=True)
    add_isdominated_cols(dfs[i])
    dfs[i].sort_values(by=objs_cols[0], inplace=True)
# Out:
# Reading file: final/Analises/MOEAD_results_01.csv
# Reading file: final/Analises/MOEAD_results_02.csv
# Reading file: final/Analises/MOEAD_results_03.csv
# Reading file: final/Analises/SPEA2_results_01.csv
# Reading file: final/Analises/SPEA2_results_02.csv
# Reading file: final/Analises/SPEA2_results_03.csv
# Reading file: final/Analises/NSGAII_results_01.csv
# Reading file: final/Analises/NSGAII_results_02.csv
# Reading file: final/Analises/NSGAII_results_03.csv
# Reading file: final/Analises/OMOPSO_results_01.csv
# Reading file: final/Analises/OMOPSO_results_02.csv
# Reading file: final/Analises/OMOPSO_results_03.csv
# Reading file: final/Analises/SMPSO_results_01.csv
# Reading file: final/Analises/SMPSO_results_02.csv
# Reading file: final/Analises/SMPSO_results_03.csv
# Reading file: final/Analises/PESA2_results_01.csv
# Reading file: final/Analises/PESA2_results_02.csv
# Reading file: final/Analises/PESA2_results_03.csv
# Reading file: final/Analises/PAES_results_01.csv
# Reading file: final/Analises/PAES_results_02.csv
# Reading file: final/Analises/PAES_results_03.csv
# Reading file: final/Analises/EpsMOEA_results_01.csv
# Reading file: final/Analises/EpsMOEA_results_02.csv
# Reading file: final/Analises/EpsMOEA_results_03.csv
# Reading file: final/Analises/GDE3_results_01.csv
# Reading file: final/Analises/GDE3_results_02.csv
# Reading file: final/Analises/GDE3_results_03.csv
# Reading file: final/Analises/CMAES_results_01.csv
# Reading file: final/Analises/CMAES_results_02.csv
# Reading file: final/Analises/CMAES_results_03.csv
# Reading file: final/Analises/GPR_NSGAII_results_01.csv
# Reading file: final/Analises/GPR_NSGAII_results_02.csv
# Reading file: final/Analises/GPR_NSGAII_results_03.csv
# Reading file: final/Analises/GPR_Random_results_01.csv
# Reading file: final/Analises/GPR_Random_results_02.csv
# Reading file: final/Analises/GPR_Random_results_03.csv
# Reading file: final/Analises/GPR_SMPSO_results_01.csv
# Reading file: final/Analises/GPR_SMPSO_results_02.csv
# Reading file: final/Analises/GPR_SMPSO_results_03.csv
# Reading file: final/Analises/RF_NSGAII_results_01.csv
# Reading file: final/Analises/RF_NSGAII_results_02.csv
# Reading file: final/Analises/RF_NSGAII_results_03.csv
# Reading file: final/Analises/RF_Random_results_01.csv
# Reading file: final/Analises/RF_Random_results_02.csv
# Reading file: final/Analises/RF_Random_results_03.csv
# Reading file: final/Analises/RF_SMPSO_results_01.csv
# Reading file: final/Analises/RF_SMPSO_results_02.csv
# Reading file: final/Analises/RF_SMPSO_results_03.csv
# Reading file: final/Analises/MLP_NSGAII_results_01.csv
# Reading file: final/Analises/MLP_NSGAII_results_02.csv
# Reading file: final/Analises/MLP_NSGAII_results_03.csv
# Reading file: final/Analises/MLP_Random_results_01.csv
# Reading file: final/Analises/MLP_Random_results_02.csv
# Reading file: final/Analises/MLP_Random_results_03.csv
# Reading file: final/Analises/MLP_SMPSO_results_01.csv
# Reading file: final/Analises/MLP_SMPSO_results_02.csv
# Reading file: final/Analises/MLP_SMPSO_results_03.csv
# 	Algorithm_run  ('MOEAD', 1)
# Retrieved 254 solutions
# 1.0    223
# 0.0     31
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('MOEAD', 2)
# Retrieved 254 solutions
# 1.0    216
# 0.0     38
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('MOEAD', 3)
# Retrieved 254 solutions
# 1.0    234
# 0.0     20
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('SPEA2', 1)
# Retrieved 234 solutions
# 1.0    207
# 0.0     27
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('SPEA2', 2)
# Retrieved 238 solutions
# 1.0    212
# 0.0     26
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('SPEA2', 3)
# Retrieved 227 solutions
# 1.0    212
# 0.0     15
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('NSGAII', 1)
# Retrieved 239 solutions
# 1.0    208
# 0.0     31
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('NSGAII', 2)
# Retrieved 235 solutions
# 1.0    223
# 0.0     12
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('NSGAII', 3)
# Retrieved 239 solutions
# 1.0    212
# 0.0     27
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('OMOPSO', 1)
# Retrieved 225 solutions
# 1.0    213
# 0.0     12
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('OMOPSO', 2)
# Retrieved 225 solutions
# 1.0    203
# 0.0     22
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('OMOPSO', 3)
# Retrieved 225 solutions
# 1.0    214
# 0.0     11
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('SMPSO', 1)
# Retrieved 225 solutions
# 1.0    194
# 0.0     31
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('SMPSO', 2)
# Retrieved 225 solutions
# 1.0    209
# 0.0     16
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('SMPSO', 3)
# Retrieved 225 solutions
# 1.0    202
# 0.0     23
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('PESA2', 1)
# Retrieved 236 solutions
# 1.0    203
# 0.0     33
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('PESA2', 2)
# Retrieved 238 solutions
# 1.0    211
# 0.0     27
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('PESA2', 3)
# Retrieved 239 solutions
# 1.0    211
# 0.0     28
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('PAES', 1)
# Retrieved 225 solutions
# 1.0    183
# 0.0     42
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('PAES', 2)
# Retrieved 225 solutions
# 1.0    193
# 0.0     32
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('PAES', 3)
# Retrieved 225 solutions
# 1.0    185
# 0.0     40
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('EpsMOEA', 1)
# Retrieved 225 solutions
# 1.0    201
# 0.0     24
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('EpsMOEA', 2)
# Retrieved 226 solutions
# 1.0    194
# 0.0     32
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('EpsMOEA', 3)
# Retrieved 226 solutions
# 1.0    191
# 0.0     35
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GDE3', 1)
# Retrieved 225 solutions
# 1.0    208
# 0.0     17
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GDE3', 2)
# Retrieved 225 solutions
# 1.0    204
# 0.0     21
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GDE3', 3)
# Retrieved 225 solutions
# 1.0    204
# 0.0     21
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('CMAES', 1)
# Retrieved 407 solutions
# 1.0    386
# 0.0     21
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('CMAES', 2)
# Retrieved 600 solutions
# 1.0    580
# 0.0     20
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('CMAES', 3)
# Retrieved 300 solutions
# 1.0    261
# 0.0     39
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GPR_NSGAII', 1)
# Retrieved 225 solutions
# 1.0    212
# 0.0     13
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GPR_NSGAII', 2)
# Retrieved 225 solutions
# 1.0    211
# 0.0     14
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GPR_NSGAII', 3)
# Retrieved 225 solutions
# 1.0    215
# 0.0     10
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GPR_Random', 1)
# Retrieved 226 solutions
# 1.0    221
# 0.0      5
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GPR_Random', 2)
# Retrieved 225 solutions
# 1.0    216
# 0.0      9
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GPR_Random', 3)
# Retrieved 228 solutions
# 1.0    219
# 0.0      9
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GPR_SMPSO', 1)
# Retrieved 226 solutions
# 1.0    209
# 0.0     17
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GPR_SMPSO', 2)
# Retrieved 238 solutions
# 1.0    228
# 0.0     10
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('GPR_SMPSO', 3)
# Retrieved 226 solutions
# 1.0    213
# 0.0     13
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('RF_NSGAII', 1)
# Retrieved 232 solutions
# 1.0    219
# 0.0     13
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('RF_NSGAII', 2)
# Retrieved 234 solutions
# 1.0    220
# 0.0     14
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('RF_NSGAII', 3)
# Retrieved 237 solutions
# 1.0    220
# 0.0     17
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('RF_Random', 1)
# Retrieved 229 solutions
# 1.0    218
# 0.0     11
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('RF_Random', 2)
# Retrieved 230 solutions
# 1.0    219
# 0.0     11
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('RF_Random', 3)
# Retrieved 230 solutions
# 1.0    222
# 0.0      8
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('RF_SMPSO', 1)
# Retrieved 239 solutions
# 1.0    229
# 0.0     10
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('RF_SMPSO', 2)
# Retrieved 228 solutions
# 1.0    214
# 0.0     14
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('RF_SMPSO', 3)
# Retrieved 225 solutions
# 1.0    217
# 0.0      8
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('MLP_NSGAII', 1)
# Retrieved 240 solutions
# 1.0    230
# 0.0     10
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('MLP_NSGAII', 2)
# Retrieved 227 solutions
# 1.0    219
# 0.0      8
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('MLP_NSGAII', 3)
# Retrieved 237 solutions
# 1.0    232
# 0.0      5
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('MLP_Random', 1)
# Retrieved 229 solutions
# 1.0    220
# 0.0      9
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('MLP_Random', 2)
# Retrieved 233 solutions
# 1.0    223
# 0.0     10
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('MLP_Random', 3)
# Retrieved 228 solutions
# 1.0    221
# 0.0      7
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('MLP_SMPSO', 1)
# Retrieved 231 solutions
# 1.0    222
# 0.0      9
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('MLP_SMPSO', 2)
# Retrieved 237 solutions
# 1.0    233
# 0.0      4
# Name: isDominated, dtype: int64
# 	Algorithm_run  ('MLP_SMPSO', 3)
# Retrieved 245 solutions
# 1.0    239
# 0.0      6
# Name: isDominated, dtype: int64

# %%
len(dfs)
# Out:
# 57

# %%
nd_dfs = [d[d['isDominated']==0.0] for d in dfs]

# %%
# Write
for i in range(len(algs_runs)):
    print("\tAlgorithm_run ", algs_runs[i], ">>>", len(nd_dfs[i]), "nondominated solutions")
    filename = "final/outputs/nondominated/" + algs_runs[i][0] + "_" + str(algs_runs[i][1]) + "_o1_asc.csv"
    nd_dfs[i].to_csv(filename, columns=vars_cols+objs_cols, header=False, index=False)
# Out:
# 	Algorithm_run  ('MOEAD', 1) >>> 31 nondominated solutions
# 	Algorithm_run  ('MOEAD', 2) >>> 38 nondominated solutions
# 	Algorithm_run  ('MOEAD', 3) >>> 20 nondominated solutions
# 	Algorithm_run  ('SPEA2', 1) >>> 27 nondominated solutions
# 	Algorithm_run  ('SPEA2', 2) >>> 26 nondominated solutions
# 	Algorithm_run  ('SPEA2', 3) >>> 15 nondominated solutions
# 	Algorithm_run  ('NSGAII', 1) >>> 31 nondominated solutions
# 	Algorithm_run  ('NSGAII', 2) >>> 12 nondominated solutions
# 	Algorithm_run  ('NSGAII', 3) >>> 27 nondominated solutions
# 	Algorithm_run  ('OMOPSO', 1) >>> 12 nondominated solutions
# 	Algorithm_run  ('OMOPSO', 2) >>> 22 nondominated solutions
# 	Algorithm_run  ('OMOPSO', 3) >>> 11 nondominated solutions
# 	Algorithm_run  ('SMPSO', 1) >>> 31 nondominated solutions
# 	Algorithm_run  ('SMPSO', 2) >>> 16 nondominated solutions
# 	Algorithm_run  ('SMPSO', 3) >>> 23 nondominated solutions
# 	Algorithm_run  ('PESA2', 1) >>> 33 nondominated solutions
# 	Algorithm_run  ('PESA2', 2) >>> 27 nondominated solutions
# 	Algorithm_run  ('PESA2', 3) >>> 28 nondominated solutions
# 	Algorithm_run  ('PAES', 1) >>> 42 nondominated solutions
# 	Algorithm_run  ('PAES', 2) >>> 32 nondominated solutions
# 	Algorithm_run  ('PAES', 3) >>> 40 nondominated solutions
# 	Algorithm_run  ('EpsMOEA', 1) >>> 24 nondominated solutions
# 	Algorithm_run  ('EpsMOEA', 2) >>> 32 nondominated solutions
# 	Algorithm_run  ('EpsMOEA', 3) >>> 35 nondominated solutions
# 	Algorithm_run  ('GDE3', 1) >>> 17 nondominated solutions
# 	Algorithm_run  ('GDE3', 2) >>> 21 nondominated solutions
# 	Algorithm_run  ('GDE3', 3) >>> 21 nondominated solutions
# 	Algorithm_run  ('CMAES', 1) >>> 21 nondominated solutions
# 	Algorithm_run  ('CMAES', 2) >>> 20 nondominated solutions
# 	Algorithm_run  ('CMAES', 3) >>> 39 nondominated solutions
# 	Algorithm_run  ('GPR_NSGAII', 1) >>> 13 nondominated solutions
# 	Algorithm_run  ('GPR_NSGAII', 2) >>> 14 nondominated solutions
# 	Algorithm_run  ('GPR_NSGAII', 3) >>> 10 nondominated solutions
# 	Algorithm_run  ('GPR_Random', 1) >>> 5 nondominated solutions
# 	Algorithm_run  ('GPR_Random', 2) >>> 9 nondominated solutions
# 	Algorithm_run  ('GPR_Random', 3) >>> 9 nondominated solutions
# 	Algorithm_run  ('GPR_SMPSO', 1) >>> 17 nondominated solutions
# 	Algorithm_run  ('GPR_SMPSO', 2) >>> 10 nondominated solutions
# 	Algorithm_run  ('GPR_SMPSO', 3) >>> 13 nondominated solutions
# 	Algorithm_run  ('RF_NSGAII', 1) >>> 13 nondominated solutions
# 	Algorithm_run  ('RF_NSGAII', 2) >>> 14 nondominated solutions
# 	Algorithm_run  ('RF_NSGAII', 3) >>> 17 nondominated solutions
# 	Algorithm_run  ('RF_Random', 1) >>> 11 nondominated solutions
# 	Algorithm_run  ('RF_Random', 2) >>> 11 nondominated solutions
# 	Algorithm_run  ('RF_Random', 3) >>> 8 nondominated solutions
# 	Algorithm_run  ('RF_SMPSO', 1) >>> 10 nondominated solutions
# 	Algorithm_run  ('RF_SMPSO', 2) >>> 14 nondominated solutions
# 	Algorithm_run  ('RF_SMPSO', 3) >>> 8 nondominated solutions
# 	Algorithm_run  ('MLP_NSGAII', 1) >>> 10 nondominated solutions
# 	Algorithm_run  ('MLP_NSGAII', 2) >>> 8 nondominated solutions
# 	Algorithm_run  ('MLP_NSGAII', 3) >>> 5 nondominated solutions
# 	Algorithm_run  ('MLP_Random', 1) >>> 9 nondominated solutions
# 	Algorithm_run  ('MLP_Random', 2) >>> 10 nondominated solutions
# 	Algorithm_run  ('MLP_Random', 3) >>> 7 nondominated solutions
# 	Algorithm_run  ('MLP_SMPSO', 1) >>> 9 nondominated solutions
# 	Algorithm_run  ('MLP_SMPSO', 2) >>> 4 nondominated solutions
# 	Algorithm_run  ('MLP_SMPSO', 3) >>> 6 nondominated solutions

# %%
len(algs_runs)
# Out:
# 57

# %%
for i, alg_run in enumerate(algs_runs):
    alg, run = alg_run
    o1_max, o2_max = nd_dfs[i][objs_cols].max()
    o1_min, o2_min = nd_dfs[i][objs_cols].min()
    print("Algorithm", alg, "Run", run)
    print("o1_min", o1_min, "o1_max", o1_max, "o1_dist: ", o1_max - o1_min)
    print("o2_min", o2_min, "o2_max", o2_max, "o2_dist: ", o2_max - o2_min)
    print("spread:", o2_max - o2_min)
# Out:
# Algorithm MOEAD Run 1
# o1_min 1.0505763862588902 o1_max 1.3568516503115085 o1_dist:  0.3062752640526183
# o2_min 1.6839181682760789 o2_max 60.057767024249614 o2_dist:  58.373848855973534
# spread: 58.373848855973534
# Algorithm MOEAD Run 2
# o1_min 1.0385236423527429 o1_max 1.334042787672883 o1_dist:  0.29551914532014023
# o2_min 2.7361897712814467 o2_max 55.97860503137747 o2_dist:  53.242415260096024
# spread: 53.242415260096024
# Algorithm MOEAD Run 3
# o1_min 1.0642060769335968 o1_max 1.4088104241803632 o1_dist:  0.34460434724676636
# o2_min 3.1441563394549847 o2_max 51.68791240912932 o2_dist:  48.54375606967433
# spread: 48.54375606967433
# Algorithm SPEA2 Run 1
# o1_min 1.0516599207859822 o1_max 1.3465019137184868 o1_dist:  0.29484199293250457
# o2_min 8.710930549628845 o2_max 56.63729404022826 o2_dist:  47.926363490599414
# spread: 47.926363490599414
# Algorithm SPEA2 Run 2
# o1_min 1.0597988813058838 o1_max 1.2920837004300152 o1_dist:  0.23228481912413135
# o2_min 7.245905553017132 o2_max 45.719547057115896 o2_dist:  38.473641504098765
# spread: 38.473641504098765
# Algorithm SPEA2 Run 3
# o1_min 0.8677812421064868 o1_max 1.168201155361278 o1_dist:  0.30041991325479134
# o2_min 10.068176282877793 o2_max 56.14244132528634 o2_dist:  46.07426504240855
# spread: 46.07426504240855
# Algorithm NSGAII Run 1
# o1_min 1.0571959645692075 o1_max 1.2794958086670052 o1_dist:  0.22229984409779768
# o2_min 7.251966865547733 o2_max 47.262400611973455 o2_dist:  40.01043374642572
# spread: 40.01043374642572
# Algorithm NSGAII Run 2
# o1_min 0.861040923361066 o1_max 1.2646659173419776 o1_dist:  0.4036249939809117
# o2_min 8.311706966850723 o2_max 53.6709666833069 o2_dist:  45.35925971645618
# spread: 45.35925971645618
# Algorithm NSGAII Run 3
# o1_min 0.902902840972984 o1_max 1.2878668565279818 o1_dist:  0.3849640155549978
# o2_min 8.626306551345907 o2_max 66.81862381665354 o2_dist:  58.192317265307636
# spread: 58.192317265307636
# Algorithm OMOPSO Run 1
# o1_min 0.6642012176537696 o1_max 1.2903317927844138 o1_dist:  0.6261305751306442
# o2_min 8.225770998503384 o2_max 39.975111357161055 o2_dist:  31.74934035865767
# spread: 31.74934035865767
# Algorithm OMOPSO Run 2
# o1_min 0.6006835260172844 o1_max 1.3131493378131784 o1_dist:  0.7124658117958941
# o2_min 7.7572978743451335 o2_max 74.68763432916434 o2_dist:  66.93033645481921
# spread: 66.93033645481921
# Algorithm OMOPSO Run 3
# o1_min 0.7697980773124556 o1_max 1.2608041336485292 o1_dist:  0.4910060563360735
# o2_min 7.82587194784389 o2_max 73.29606706827141 o2_dist:  65.47019512042752
# spread: 65.47019512042752
# Algorithm SMPSO Run 1
# o1_min 0.701265924988076 o1_max 1.3087223923157305 o1_dist:  0.6074564673276545
# o2_min 0.0 o2_max 88.61695571145277 o2_dist:  88.61695571145277
# spread: 88.61695571145277
# Algorithm SMPSO Run 2
# o1_min 0.576628801595128 o1_max 1.3087223923156872 o1_dist:  0.7320935907205592
# o2_min 0.0 o2_max 78.07276970144287 o2_dist:  78.07276970144287
# spread: 78.07276970144287
# Algorithm SMPSO Run 3
# o1_min 0.6000491557999114 o1_max 1.3087223923156133 o1_dist:  0.7086732365157019
# o2_min 0.0 o2_max 40.92809388024375 o2_dist:  40.92809388024375
# spread: 40.92809388024375
# Algorithm PESA2 Run 1
# o1_min 1.0319028357641673 o1_max 1.4377071472388725 o1_dist:  0.4058043114747052
# o2_min 6.964341902280951 o2_max 54.27021236675228 o2_dist:  47.30587046447133
# spread: 47.30587046447133
# Algorithm PESA2 Run 2
# o1_min 1.0633858180075246 o1_max 1.2630132655966897 o1_dist:  0.19962744758916506
# o2_min 8.894984555710046 o2_max 61.83466259518146 o2_dist:  52.93967803947142
# spread: 52.93967803947142
# Algorithm PESA2 Run 3
# o1_min 0.977276303500076 o1_max 1.2307508356446468 o1_dist:  0.25347453214457083
# o2_min 14.994435161065807 o2_max 64.07356820089532 o2_dist:  49.079133039829514
# spread: 49.079133039829514
# Algorithm PAES Run 1
# o1_min 1.0732629686821036 o1_max 1.3035305029207305 o1_dist:  0.2302675342386269
# o2_min 6.412906730186094 o2_max 45.73602977279904 o2_dist:  39.32312304261295
# spread: 39.32312304261295
# Algorithm PAES Run 2
# o1_min 1.1820745815300768 o1_max 1.269674723331698 o1_dist:  0.08760014180162123
# o2_min 1.2179146071402212 o2_max 17.998051958068324 o2_dist:  16.7801373509281
# spread: 16.7801373509281
# Algorithm PAES Run 3
# o1_min 0.9402221801063406 o1_max 1.1678811190095313 o1_dist:  0.22765893890319067
# o2_min 32.65106048765929 o2_max 63.994511949579646 o2_dist:  31.34345146192036
# spread: 31.34345146192036
# Algorithm EpsMOEA Run 1
# o1_min 1.0614217936408878 o1_max 1.2317532166765903 o1_dist:  0.17033142303570248
# o2_min 10.06208808344401 o2_max 49.11753712868265 o2_dist:  39.05544904523864
# spread: 39.05544904523864
# Algorithm EpsMOEA Run 2
# o1_min 1.007607799701915 o1_max 1.2622373912363718 o1_dist:  0.25462959153445675
# o2_min 17.758730609932535 o2_max 54.94887633278303 o2_dist:  37.190145722850495
# spread: 37.190145722850495
# Algorithm EpsMOEA Run 3
# o1_min 0.9820249535304492 o1_max 1.390600234695294 o1_dist:  0.40857528116484476
# o2_min 3.8074628948751537 o2_max 61.39856015138851 o2_dist:  57.59109725651336
# spread: 57.59109725651336
# Algorithm GDE3 Run 1
# o1_min 0.695300322847316 o1_max 1.1999173096747635 o1_dist:  0.5046169868274475
# o2_min 7.844353517358721 o2_max 74.89202132379535 o2_dist:  67.04766780643662
# spread: 67.04766780643662
# Algorithm GDE3 Run 2
# o1_min 0.7759716513162406 o1_max 1.2534601813041202 o1_dist:  0.4774885299878796
# o2_min 9.592012865326355 o2_max 65.93682316431202 o2_dist:  56.344810298985664
# spread: 56.344810298985664
# Algorithm GDE3 Run 3
# o1_min 0.7927796242606084 o1_max 1.288412069412647 o1_dist:  0.49563244515203864
# o2_min 2.5180176398970646 o2_max 59.23899779114803 o2_dist:  56.72098015125096
# spread: 56.72098015125096
# Algorithm CMAES Run 1
# o1_min 1.0478943286251945 o1_max 1.2967706723788397 o1_dist:  0.2488763437536452
# o2_min 18.25886854791002 o2_max 58.20565139480976 o2_dist:  39.946782846899744
# spread: 39.946782846899744
# Algorithm CMAES Run 2
# o1_min 1.005390931265452 o1_max 1.2142860546112595 o1_dist:  0.2088951233458074
# o2_min 32.06259249710716 o2_max 58.97090948337402 o2_dist:  26.90831698626686
# spread: 26.90831698626686
# Algorithm CMAES Run 3
# o1_min 1.0558205258770483 o1_max 1.3780611998082135 o1_dist:  0.3222406739311652
# o2_min 22.16316343025372 o2_max 46.73966865272982 o2_dist:  24.576505222476097
# spread: 24.576505222476097
# Algorithm GPR_NSGAII Run 1
# o1_min 1.086887885321003 o1_max 1.3243927927304608 o1_dist:  0.23750490740945773
# o2_min 1.867445996571791 o2_max 54.852049596866635 o2_dist:  52.98460360029485
# spread: 52.98460360029485
# Algorithm GPR_NSGAII Run 2
# o1_min 1.0503541511252672 o1_max 1.326278263678113 o1_dist:  0.27592411255284577
# o2_min 4.7985255706882475 o2_max 43.58797152047058 o2_dist:  38.78944594978233
# spread: 38.78944594978233
# Algorithm GPR_NSGAII Run 3
# o1_min 1.0642913506907514 o1_max 1.3245588566592812 o1_dist:  0.26026750596852977
# o2_min 6.1525716333279465 o2_max 48.761816258478774 o2_dist:  42.60924462515083
# spread: 42.60924462515083
# Algorithm GPR_Random Run 1
# o1_min 1.0727704661736421 o1_max 1.239787725858742 o1_dist:  0.16701725968509984
# o2_min 9.567052643056003 o2_max 27.8888003599686 o2_dist:  18.321747716912597
# spread: 18.321747716912597
# Algorithm GPR_Random Run 2
# o1_min 1.054265630075992 o1_max 1.3220120668142306 o1_dist:  0.2677464367382385
# o2_min 8.810639226965842 o2_max 44.620654986596534 o2_dist:  35.810015759630694
# spread: 35.810015759630694
# Algorithm GPR_Random Run 3
# o1_min 1.0284155097673495 o1_max 1.3241739738212468 o1_dist:  0.2957584640538973
# o2_min 11.850983888575929 o2_max 57.78098385097528 o2_dist:  45.92999996239935
# spread: 45.92999996239935
# Algorithm GPR_SMPSO Run 1
# o1_min 0.7290265057849237 o1_max 1.324049367755236 o1_dist:  0.5950228619703124
# o2_min 0.0 o2_max 48.47348846735662 o2_dist:  48.47348846735662
# spread: 48.47348846735662
# Algorithm GPR_SMPSO Run 2
# o1_min 1.006769142675728 o1_max 1.324049367754804 o1_dist:  0.31728022507907605
# o2_min 0.0 o2_max 28.03856998015468 o2_dist:  28.03856998015468
# spread: 28.03856998015468
# Algorithm GPR_SMPSO Run 3
# o1_min 1.0362382570908062 o1_max 1.3240493677547984 o1_dist:  0.28781111066399223
# o2_min 0.0 o2_max 48.5332144293604 o2_dist:  48.5332144293604
# spread: 48.5332144293604
# Algorithm RF_NSGAII Run 1
# o1_min 1.0169073431764029 o1_max 1.3156433314109603 o1_dist:  0.2987359882345575
# o2_min 10.117693686883696 o2_max 52.37009143353463 o2_dist:  42.252397746650935
# spread: 42.252397746650935
# Algorithm RF_NSGAII Run 2
# o1_min 1.0418204736484529 o1_max 1.3147910496514292 o1_dist:  0.27297057600297636
# o2_min 4.609279488352787 o2_max 51.389025407922595 o2_dist:  46.779745919569805
# spread: 46.779745919569805
# Algorithm RF_NSGAII Run 3
# o1_min 1.0315352358101515 o1_max 1.230482886058786 o1_dist:  0.19894765024863448
# o2_min 10.998636769833613 o2_max 48.17373784971674 o2_dist:  37.17510107988312
# spread: 37.17510107988312
# Algorithm RF_Random Run 1
# o1_min 1.058928007836145 o1_max 1.2681967158940295 o1_dist:  0.20926870805788456
# o2_min 8.698089715219808 o2_max 43.431965014006394 o2_dist:  34.733875298786586
# spread: 34.733875298786586
# Algorithm RF_Random Run 2
# o1_min 1.0631875747036716 o1_max 1.3200596666296416 o1_dist:  0.25687209192596994
# o2_min 6.533664560589436 o2_max 51.181755674092805 o2_dist:  44.64809111350337
# spread: 44.64809111350337
# Algorithm RF_Random Run 3
# o1_min 1.0300252786009252 o1_max 1.3221441198117811 o1_dist:  0.29211884121085596
# o2_min 8.251223208928321 o2_max 36.65950630871165 o2_dist:  28.408283099783326
# spread: 28.408283099783326
# Algorithm RF_SMPSO Run 1
# o1_min 1.0651618035447272 o1_max 1.3221435632462493 o1_dist:  0.25698175970152204
# o2_min 1.014264046057864 o2_max 49.949210490241185 o2_dist:  48.934946444183325
# spread: 48.934946444183325
# Algorithm RF_SMPSO Run 2
# o1_min 1.0409743167451744 o1_max 1.3979530410818235 o1_dist:  0.3569787243366491
# o2_min 0.0 o2_max 43.55163361527698 o2_dist:  43.55163361527698
# spread: 43.55163361527698
# Algorithm RF_SMPSO Run 3
# o1_min 1.0628676640680317 o1_max 1.2379974157520948 o1_dist:  0.17512975168406308
# o2_min 6.665229342637056 o2_max 41.54566573633886 o2_dist:  34.88043639370181
# spread: 34.88043639370181
# Algorithm MLP_NSGAII Run 1
# o1_min 0.786686541639575 o1_max 1.433670112595359 o1_dist:  0.6469835709557841
# o2_min 2.7589062007246383 o2_max 43.69261940214162 o2_dist:  40.93371320141698
# spread: 40.93371320141698
# Algorithm MLP_NSGAII Run 2
# o1_min 1.08443002707915 o1_max 1.4057139692344744 o1_dist:  0.3212839421553244
# o2_min 4.160658046088538 o2_max 39.90699938595329 o2_dist:  35.746341339864756
# spread: 35.746341339864756
# Algorithm MLP_NSGAII Run 3
# o1_min 1.056969761290137 o1_max 1.4183860935211687 o1_dist:  0.36141633223103176
# o2_min 3.081874034642781 o2_max 13.269925817133458 o2_dist:  10.188051782490678
# spread: 10.188051782490678
# Algorithm MLP_Random Run 1
# o1_min 1.0195324966342514 o1_max 1.3221388786512505 o1_dist:  0.3026063820169991
# o2_min 4.34153719643751 o2_max 43.51827073376354 o2_dist:  39.17673353732604
# spread: 39.17673353732604
# Algorithm MLP_Random Run 2
# o1_min 1.088071500490859 o1_max 1.269818456252636 o1_dist:  0.18174695576177702
# o2_min 12.171104828738315 o2_max 49.265207539656714 o2_dist:  37.0941027109184
# spread: 37.0941027109184
# Algorithm MLP_Random Run 3
# o1_min 1.0420018459327045 o1_max 1.3472843342446483 o1_dist:  0.3052824883119438
# o2_min 5.080632814903523 o2_max 40.850820562585696 o2_dist:  35.77018774768217
# spread: 35.77018774768217
# Algorithm MLP_SMPSO Run 1
# o1_min 0.8822085852424134 o1_max 1.4166709587892532 o1_dist:  0.5344623735468398
# o2_min 0.1529763323485669 o2_max 44.3519167613521 o2_dist:  44.198940429003535
# spread: 44.198940429003535
# Algorithm MLP_SMPSO Run 2
# o1_min 1.0047003165263066 o1_max 1.422934030669332 o1_dist:  0.41823371414302546
# o2_min 1.5193521806902586 o2_max 33.09194339252188 o2_dist:  31.572591211831618
# spread: 31.572591211831618
# Algorithm MLP_SMPSO Run 3
# o1_min 1.0292287592636535 o1_max 1.4231021292463182 o1_dist:  0.39387336998266465
# o2_min 1.1850757207044025 o2_max 50.644978087816035 o2_dist:  49.45990236711163
# spread: 49.45990236711163

# %% [markdown]
# # Data Visualization

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
plotly.__version__
# Out:
# '3.7.1'

# %%
# plotly.tools.set_credentials_file(username='PastelBelem8', api_key='X8k1mloXRlB24rZm0qyq')
plotly.tools.set_credentials_file(username='KatarinaBelem', api_key='u5cJ4twW7lnZi128Bgjm')

# %%
layout = go.Layout(
    # title = "Solutions of the minimization of two goals of an arc-shaped space frame",
    showlegend=True,
    # showlegend=False,
    autosize=False,
        # Definir tamanho do gráfico
    width=1000,
    height=600,
    legend=dict(orientation="v", 
                #xanchor="center", 
                #yanchor="bottom",
                #x= 0.5,
                #y=-0.5
               ),
    xaxis=dict(
        title="Maximum Displacement",
        range=[0.57, 1.45], 
        # autorange=True,
        showgrid=True,
        zeroline=False,
        showline=True,
        ticks='',
        showticklabels=True
    ),
    yaxis=dict(
        title="Attractors Distance",
        range=[0, 90],
        # autorange=True,        
        showgrid=True,
        zeroline=False,
        showline=True,
        ticks='',
        showticklabels=True
    )
    )

# %%
colors = [
    # Verde
    'rgb(81, 142, 12)',
    # Vermelho
    'rgb(165, 0, 0)',
    # Roxo
    'rgb(152, 64, 188)',
    # Azul 
    'rgb(13, 188, 188)', 
    # Amarelo
    'rgb(255, 165, 21)',
    # Rosa
    'rgb(219, 31, 152)',
    # Cinzento claro
    'rgb(119, 130, 118)',
    # Azul escuro
    'rgb(0, 0, 255)',
    # Castanho
    'rgb(128, 64, 0)',
    
    # Metamodels
    # Bubblegum 1
    'rgb(128, 204, 204)',
    # Blanched almond 2
    'rgb(128, 238, 204)',
    # Goldenrod yellow 3
    'rgb(238, 128, 102)',
    # Mint Green 4
    'rgb(128, 255, 170)',
    # Electric Blue 5
    'rgb(102, 255, 255)',
    # Ultramarine blue 6
    'rgb(51, 119, 255)',
    # Pale cornflower blue 7
    'rgb(179, 191, 255)',
    # Lavender floral 8
    'rgb(170, 128, 255)',
    # Shocking pink 9
    'rgb(255,105,180)',
    # Preto
    'rgb(0, 100, 0)'
    ]

# %%
nruns = len(runs)

# %%
algs_runs[0]
# Out:
# ('MOEAD', 1)

# %%
# Out:
#            O1         O2
# 243  1.318520   6.143293
# 218  1.107151  53.311779
# 215  1.339571   2.856120
# 209  1.122551  50.386877
# 199  1.335165   4.991244
# 249  1.338342   3.242738
# 185  1.325452   5.763391
# 174  1.303779  12.521745
# 172  1.356852   1.683918
# 168  1.336788   4.030568
# 160  1.115430  53.086092
# 152  1.109946  53.206369
# 150  1.301679  15.777787
# 140  1.131506  46.124179
# 131  1.335641   4.808695
# 252  1.331542   5.321028
# 113  1.308521  11.537865
# 107  1.335670   4.808131
# 90   1.270803  24.531840
# 81   1.297017  19.369832
# 23   1.050576  60.057767
# 70   1.150518  45.026433
# 61   1.152383  35.696483
# 219  1.107836  53.252608
# 225  1.107057  53.313762
# 224  1.327429   5.471556
# 244  1.344950   2.644533
# 12   1.170703  32.813286
# 239  1.338296   3.993077
# 247  1.313088   9.251918
# 231  1.112827  53.153273

# %%
def create_plots_per_run(data=dfs, runs=[1, 2, 3], combinedPf=None, colors=colors):
    # Create traces for each algorithm
    traces = []
    for j, alg_run in enumerate(algs_runs):
        a, i = alg_run
        if i in runs:
            datum = data[j]
            color = colors[j // nruns]
            trace1 = go.Scatter(
                        x = datum[datum['isDominated'] == 0][objs_cols[0]],
                        y = datum[datum['isDominated'] == 0][objs_cols[1]],
                        # legendgroup = a,
                        name = a ,
                        mode = 'lines+markers',
                        marker=dict(
                            size=5,
                            color = color,
                            opacity=1
                        ),
                        line=dict(
                            width = 1,
                            color = color
                        ))
            # trace2 = go.Scatter(
            #            x = datum[datum['isDominated'] == 1][get_objs_cols(datum)[0]],
            #            y = datum[datum['isDominated'] == 1][get_objs_cols(datum)[1]],
            #            legendgroup = a + "Run_" + str(j % nruns + 1),
            #            name = a + " dominated_Run_" + str(j % nruns + 1),
            #            mode = 'markers',
            #            marker=dict(
            #                size=2.5,
            #                color = color,
            #                opacity=0.8
            #            ))

            # traces += [trace1, trace2]
            traces += [trace1]
            
    if combinedPf is not None:
        tpf_o1 = combinedPf[combinedPf['isDominated'] == 0][9]
        tpf_o2 = combinedPf[combinedPf['isDominated'] == 0][10]

        # Add True PF
        tpf_trace = go.Scatter(
            x = tpf_o1,
            y = tpf_o2,
            mode = 'markers',
            name = "Combined",
            marker=dict(
                size=6,
                color = 'rgb(16, 46, 51)',
                opacity=1
                #line = dict(
                #     color = 'rgb(255, 255, 255)',
                #      width = 0.25
                # )
                )
            )
        traces.append(tpf_trace)

    fig = go.Figure(data=traces, layout=layout)
    return fig, py.iplot(fig, filename='AllAlgorithms-perrun')

# %%
fig, graph = create_plots_per_run(runs=[1])
graph
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~KatarinaBelem/66.embed" height="600px" width="1000px"></iframe>

# %%
tpf_file1 = "all_solutions_r1.csv"
tpf_file2 = "all_solutions_r2.csv"
tpf_file3 = "all_solutions_r3.csv"
def get_true_pf_data(file="all_solutions.csv", folder="final/outputs/"):
    file = folder + file
    return pd.read_csv(file, sep=',', header=None)

def process_pf(d, cols):
    drop_cols = [0, 1, 2]
    d.drop(drop_cols, axis=1, inplace=True)
    add_isdominated_cols(d, cols)
    d.sort_values(by=9, inplace=True)

# %%
TPF = get_true_pf_data()
process_pf(TPF, cols=[9, 10])
print("True Pareto Front")
TPF.describe()
# Out:
# 1.0    13098
# 0.0       29
# Name: isDominated, dtype: int64
# True Pareto Front
#                   3             4             5             6             7  \
# count  13127.000000  13127.000000  13127.000000  13127.000000  13127.000000
# mean       0.094451     11.305438      0.031115     12.269042      0.104918
# std        1.458253      8.594749      1.420494      8.676885      1.420706
# min       -3.141593      0.000000     -3.141593      0.000000     -3.141593
# 25%       -1.076730      4.695171     -0.946134      5.205467     -0.856511
# 50%        0.198772      9.227895      0.007949     10.857222      0.192907
# 75%        1.209640     17.865079      1.057523     19.142639      1.047754
# max        3.141593     31.415927      3.141593     31.415927      3.141593
#
#                   8             9            10   isDominated   dominatedBy
# count  13127.000000  13127.000000  13127.000000  13127.000000  13127.000000
# mean      11.424604      1.238065     36.455957      0.997791    135.200198
# std        7.888527      0.127045     15.030035      0.046952    620.651702
# min        0.000000      0.576629      0.000000      0.000000      0.000000
# 25%        5.206773      1.164542     25.981562      1.000000      2.000000
# 50%       10.340407      1.250986     38.197281      1.000000     16.000000
# 75%       17.397197      1.324189     46.941621      1.000000     59.000000
# max       31.415927      1.857447     88.896425      1.000000  13080.000000

# %%
TPF1 = get_true_pf_data(tpf_file1)
process_pf(TPF1, cols=[9, 10])
TPF2 = get_true_pf_data(tpf_file2)
process_pf(TPF2, cols=[9, 10])
TPF3 = get_true_pf_data(tpf_file3)
process_pf(TPF3, cols=[9, 10])
# Out:
# 1.0    4332
# 0.0      14
# Name: isDominated, dtype: int64
# 1.0    4519
# 0.0      24
# Name: isDominated, dtype: int64
# 1.0    4219
# 0.0      19
# Name: isDominated, dtype: int64

# %%
TPF.sort_values(by=9, inplace=True)

# %%
import plotly.io as pio

# %%
fig, graph = create_plots_per_run(runs=[1], combinedPf=TPF)
graph
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~KatarinaBelem/66.embed" height="600px" width="1000px"></iframe>

# %%
fig1, graph = create_plots_per_run(runs=[1], combinedPf=TPF1)
graph
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~KatarinaBelem/66.embed" height="600px" width="1000px"></iframe>

# %%
fig2, graph = create_plots_per_run(runs=[2], combinedPf=TPF2)
graph
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~KatarinaBelem/66.embed" height="600px" width="1000px"></iframe>

# %%
fig3, graph = create_plots_per_run(runs=[3], combinedPf=TPF3)
graph
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~KatarinaBelem/66.embed" height="600px" width="1000px"></iframe>

# %%
pio.write_image(fig1, 'all_pfs_r1.svg', format='svg')
pio.write_image(fig2, 'all_pfs_r2.svg', format='svg')
pio.write_image(fig3, 'all_pfs_r3.svg', format='svg')
